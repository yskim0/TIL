# %%
import numpy as np
import tensorflow as tf
import random

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_test = x_test/255
x_train = x_train/255
x_train = x_train.reshape(x_train.shape[0],28, 28, 1)
x_test = x_test.reshape(x_test.shape[0],28, 28, 1)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
learning_rate = 0.001
training_epochs = 12
batch_size = 128

# %%
tf.model = tf.keras.Sequential()

# %%
#L1
tf.model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3),
                                   input_shape=(28,28,1),
                                   activation='relu'))
tf.model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))

# %%
#L2
tf.model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3),
                                   activation='relu'))
tf.model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))

# %%
#L3 fully connected
tf.model.add(tf.keras.layers.Flatten())
tf.model.add(tf.keras.layers.Dense(units=10, kernel_initializer='glorot_normal',
                                  activation='softmax'))

# %%
tf.model.compile(loss='categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(lr=learning_rate),
                metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 26, 26, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                8010
# ...
# Total params: 12,810
# Trainable params: 12,810
# Non-trainable params: 0
# ...

# %%
tf.model.fit(x_train, y_train, batch_size=batch_size, epochs=training_epochs)
# Out:
# Train on 60000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.3555 - accuracy: 0.8984
# Epoch 2/12
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.1048 - accuracy: 0.9682
# Epoch 3/12
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0766 - accuracy: 0.9769
# Epoch 4/12
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.0626 - accuracy: 0.9811
# Epoch 5/12
# 60000/60000 [==============================] - 11s 175us/sample - loss: 0.0532 - accuracy: 0.9840
# Epoch 6/12
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0471 - accuracy: 0.9858
# Epoch 7/12
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0416 - accuracy: 0.9876
# Epoch 8/12
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.0382 - accuracy: 0.9884
# Epoch 9/12
# ...

# %%
y_predicted = tf.model.predict(x_test)
for x in range(0, 10):
    random_index = random.randint(0, x_test.shape[0]-1)
    print("index: ", random_index,
          "actual y: ", np.argmax(y_test[random_index]),
          "predicted y: ", np.argmax(y_predicted[random_index]))

evaluation = tf.model.evaluate(x_test, y_test)
print('loss: ', evaluation[0])
print('accuracy', evaluation[1])
# Out:
# index:  1183 actual y:  9 predicted y:  9
# index:  7250 actual y:  3 predicted y:  3
# index:  4931 actual y:  1 predicted y:  1
# index:  5199 actual y:  6 predicted y:  6
# index:  3251 actual y:  0 predicted y:  0
# index:  4624 actual y:  7 predicted y:  7
# index:  2314 actual y:  7 predicted y:  7
# index:  2602 actual y:  2 predicted y:  2
# index:  8490 actual y:  0 predicted y:  0
# index:  8122 actual y:  5 predicted y:  5
# ...
